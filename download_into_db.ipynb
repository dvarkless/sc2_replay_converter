# %%
from pathlib import Path

from replay_process import ReplayProcess, ReplayFilter
from replay_downloader import ReplayDownloader
from datetime import datetime

# %%
import nest_asyncio
nest_asyncio.apply()

# %%
REPLAY_DIR = "../replays"
DATABASE_CONFIG = "./configs/database.yml"
SECRETS = "./configs/secrets.yml"
DOWNLOADER_CONFIG = "./configs/downloader_config.yml"
GAME_INFO_FILE = "./starcraft2_replay_parse/game_info.csv"

# %%
downloader = ReplayDownloader(REPLAY_DIR, DOWNLOADER_CONFIG, max_count=500, jupyter=True)

# %%
downloader.start_download("sc2rep")

# %%
downloader.start_download("spawningtool")

# %%
processor = ReplayProcess(
    SECRETS,
    DATABASE_CONFIG,
    GAME_INFO_FILE,
    jupyter=True
)

# %%
replay_filter = ReplayFilter()
replay_filter.is_1v1 = True
replay_filter.game_len = [1920, 28800]
replay_filter.time_played = datetime(2021, 1, 1)
# Out:
# For filter 'is_ladder' selected action is 'disable' (None)
# For filter 'league' selected action is 'disable' (None)
# For filter 'time_played' selected action is 'disable' (None)
# For filter 'is_1v1' selected action is 'disable' (None)
# For filter 'has_race' selected action is 'disable' (None)
# For filter 'matchup' selected action is 'disable' (None)
# For filter 'game_len' selected action is 'disable' (None)
# For filter 'is_1v1' selected action is 'valid' (True)
# For filter 'game_len' selected action is 'valid' ([1920, 28800])
# For filter 'time_played' selected action is 'valid' (2021-01-01 00:00:00)

# %%
processor.process_replays(REPLAY_DIR, filt=replay_filter)
# Out:
# on 7: Replay skipped, reason:
#       Stopped by filter: ! is_ladder==>Pass
#       ! league==>Pass
#       ! time_played==>Pass
#       ! is_1v1==>Pass
#       ! has_race==>Pass
#       ! matchup==>Pass
#       game_len==>Fail
# on 8: Replay skipped, reason:
#       Stopped by filter: ! is_ladder==>Pass
#       ! league==>Pass
#       ! time_played==>Pass
#       ! is_1v1==>Pass
#       ! has_race==>Pass
#       ! matchup==>Pass
#       game_len==>Fail
# on 33: Replay skipped, reason:
#        Stopped by filter: ! is_ladder==>Pass
#        ! league==>Pass
#        ! time_played==>Pass
#        ! is_1v1==>Pass
#        ! has_race==>Pass
#        ! matchup==>Pass
#        game_len==>Fail
# on 34: Replay skipped, reason:
#        Stopped by filter: ! is_ladder==>Pass
#        ! league==>Pass
#        ! time_played==>Pass
#        ! is_1v1==>Pass
#        ! has_race==>Pass
#        ! matchup==>Pass
#        game_len==>Fail
# on 56: Replay skipped, reason:
#        Stopped by filter: ! is_ladder==>Pass
#        ! league==>Pass
#        ! time_played==>Pass
#        ! is_1v1==>Pass
#        ! has_race==>Pass
#        ! matchup==>Pass
#        game_len==>Fail
# on 66: Replay skipped, reason:
#        Stopped by filter: ! is_ladder==>Pass
#        ! league==>Pass
#        ! time_played==>Pass
#        ! is_1v1==>Pass
#        ! has_race==>Pass
#        ! matchup==>Pass
#        game_len==>Fail
# on 71: Replay skipped, reason:
#        Stopped by filter: ! is_ladder==>Pass
#        ! league==>Pass
#        ! time_played==>Pass
#        ! is_1v1==>Pass
#        ! has_race==>Pass
#        ! matchup==>Pass
#        game_len==>Fail
# on 77: Replay skipped, reason:
#        Stopped by filter: ! is_ladder==>Pass
#        ! league==>Pass
#        ! time_played==>Pass
#        ! is_1v1==>Pass
#        ! has_race==>Pass
#        ! matchup==>Pass
#        game_len==>Fail
# on 82: Replay skipped, reason:
#        Stopped by filter: ! is_ladder==>Pass
#        ! league==>Pass
#        ! time_played==>Pass
#        ! is_1v1==>Pass
#        ! has_race==>Pass
#        ! matchup==>Pass
#        game_len==>Fail
# on 87: Replay skipped, reason:
#        Stopped by filter: ! is_ladder==>Pass
#        ! league==>Pass
#        ! time_played==>Pass
#        ! is_1v1==>Pass
#        ! has_race==>Pass
#        ! matchup==>Pass
#        game_len==>Fail
# on 88: Replay skipped, reason:
#        Stopped by filter: ! is_ladder==>Pass
#        ! league==>Pass
#        ! time_played==>Pass
#        ! is_1v1==>Pass
#        ! has_race==>Pass
#        ! matchup==>Pass
#        game_len==>Fail
# on 96: Replay skipped, reason:
#        Stopped by filter: ! is_ladder==>Pass
#        ! league==>Pass
#        ! time_played==>Pass
#        ! is_1v1==>Pass
#        ! has_race==>Pass
#        ! matchup==>Pass
#        game_len==>Fail
# on 112: Replay skipped, reason:
#         Stopped by filter: ! is_ladder==>Pass
#         ! league==>Pass
#         ! time_played==>Pass
#         ! is_1v1==>Pass
#         ! has_race==>Pass
#         ! matchup==>Pass
#         game_len==>Fail
# on 116: Replay skipped, reason:
#         Stopped by filter: ! is_ladder==>Pass
#         ! league==>Pass
#         ! time_played==>Pass
#         ! is_1v1==>Pass
#         ! has_race==>Pass
#         ! matchup==>Pass
#         game_len==>Fail
# on 117: Replay skipped, reason:
#         Stopped by filter: ! is_ladder==>Pass
#         ! league==>Pass
#         ! time_played==>Pass
#         ! is_1v1==>Pass
#         ! has_race==>Pass
#         ! matchup==>Pass
#         game_len==>Fail
# on 132: Replay skipped, reason:
#         Stopped by filter: ! is_ladder==>Pass
#         ! league==>Pass
#         ! time_played==>Pass
#         ! is_1v1==>Pass
#         ! has_race==>Pass
#         ! matchup==>Pass
#         game_len==>Fail
# on 136: Replay skipped, reason:
#         Stopped by filter: ! is_ladder==>Pass
#         ! league==>Pass
#         ! time_played==>Pass
#         ! is_1v1==>Pass
#         ! has_race==>Pass
#         ! matchup==>Pass
#         game_len==>Fail
# on 137: Replay skipped, reason:
#         Stopped by filter: ! is_ladder==>Pass
#         ! league==>Pass
#         ! time_played==>Pass
#         ! is_1v1==>Pass
#         ! has_race==>Pass
#         ! matchup==>Pass
#         game_len==>Fail
# on 166: Replay skipped, reason:
#         Stopped by filter: ! is_ladder==>Pass
#         ! league==>Pass
#         ! time_played==>Pass
#         ! is_1v1==>Pass
#         ! has_race==>Pass
#         ! matchup==>Pass
#         game_len==>Fail
# on 173: Replay skipped, reason:
#         Stopped by filter: ! is_ladder==>Pass
#         ! league==>Pass
#         ! time_played==>Pass
#         ! is_1v1==>Pass
#         ! has_race==>Pass
#         ! matchup==>Pass
#         game_len==>Fail
# on 181: Replay skipped, reason:
#         Stopped by filter: ! is_ladder==>Pass
#         ! league==>Pass
#         ! time_played==>Pass
#         ! is_1v1==>Pass
#         ! has_race==>Pass
#         ! matchup==>Pass
#         game_len==>Fail
# on 213: Replay skipped, reason:
#         Stopped by filter: ! is_ladder==>Pass
#         ! league==>Pass
#         ! time_played==>Pass
#         ! is_1v1==>Pass
#         ! has_race==>Pass
#         ! matchup==>Pass
#         game_len==>Fail
# on 216: Replay skipped, reason:
#         Stopped by filter: ! is_ladder==>Pass
#         ! league==>Pass
#         ! time_played==>Pass
#         ! is_1v1==>Pass
#         ! has_race==>Pass
#         ! matchup==>Pass
#         game_len==>Fail
# on 230: Replay skipped, reason:
#         Stopped by filter: ! is_ladder==>Pass
#         ! league==>Pass
#         ! time_played==>Pass
#         ! is_1v1==>Pass
#         ! has_race==>Pass
#         ! matchup==>Pass
#         game_len==>Fail
# on 233: Replay skipped, reason:
#         Stopped by filter: ! is_ladder==>Pass
#         ! league==>Pass
#         ! time_played==>Pass
#         ! is_1v1==>Pass
#         ! has_race==>Pass
#         ! matchup==>Pass
#         game_len==>Fail
# on 240: Replay skipped, reason:
#         Stopped by filter: ! is_ladder==>Pass
#         ! league==>Pass
#         ! time_played==>Pass
#         ! is_1v1==>Pass
#         ! has_race==>Pass
#         ! matchup==>Pass
#         game_len==>Fail
# on 247: Replay skipped, reason:
#         Stopped by filter: ! is_ladder==>Pass
#         ! league==>Pass
#         ! time_played==>Pass
#         ! is_1v1==>Pass
#         ! has_race==>Pass
#         ! matchup==>Pass
#         game_len==>Fail
# on 248: Replay skipped, reason:
#         Stopped by filter: ! is_ladder==>Pass
#         ! league==>Pass
#         ! time_played==>Pass
#         ! is_1v1==>Pass
#         ! has_race==>Pass
#         ! matchup==>Pass
#         game_len==>Fail
# on 265: Replay skipped, reason:
#         Stopped by filter: ! is_ladder==>Pass
#         ! league==>Pass
#         ! time_played==>Pass
#         ! is_1v1==>Pass
#         ! has_race==>Pass
#         ! matchup==>Pass
#         game_len==>Fail
# on 267: Replay skipped, reason:
#         Stopped by filter: ! is_ladder==>Pass
#         ! league==>Pass
#         ! time_played==>Pass
#         ! is_1v1==>Pass
#         ! has_race==>Pass
#         ! matchup==>Pass
#         game_len==>Fail
# on 274: Replay skipped, reason:
#         Stopped by filter: ! is_ladder==>Pass
#         ! league==>Pass
#         ! time_played==>Pass
#         ! is_1v1==>Pass
#         ! has_race==>Pass
#         ! matchup==>Pass
#         game_len==>Fail
# on 276: Replay skipped, reason:
#         Stopped by filter: ! is_ladder==>Pass
#         ! league==>Pass
#         ! time_played==>Pass
#         ! is_1v1==>Pass
#         ! has_race==>Pass
#         ! matchup==>Pass
#         game_len==>Fail
# on 277: Replay skipped, reason:
#         Stopped by filter: ! is_ladder==>Pass
#         ! league==>Pass
#         ! time_played==>Pass
#         ! is_1v1==>Pass
#         ! has_race==>Pass
#         ! matchup==>Pass
#         game_len==>Fail
# on 280: Replay skipped, reason:
#         Stopped by filter: ! is_ladder==>Pass
#         ! league==>Pass
#         ! time_played==>Pass
#         ! is_1v1==>Pass
#         ! has_race==>Pass
#         ! matchup==>Pass
#         game_len==>Fail
# on 285: Replay skipped, reason:
#         Stopped by filter: ! is_ladder==>Pass
#         ! league==>Pass
#         ! time_played==>Pass
#         ! is_1v1==>Pass
#         ! has_race==>Pass
#         ! matchup==>Pass
#         game_len==>Fail
# on 286: Replay skipped, reason:
#         Stopped by filter: ! is_ladder==>Pass
#         ! league==>Pass
#         ! time_played==>Pass
#         ! is_1v1==>Pass
#         ! has_race==>Pass
#         ! matchup==>Pass
#         game_len==>Fail
# on 351: Replay skipped, reason:
#         Stopped by filter: ! is_ladder==>Pass
#         ! league==>Pass
#         ! time_played==>Pass
#         ! is_1v1==>Pass
#         ! has_race==>Pass
#         ! matchup==>Pass
#         game_len==>Fail
# on 374: Replay skipped, reason:
#         Stopped by filter: ! is_ladder==>Pass
#         ! league==>Pass
#         ! time_played==>Pass
#         ! is_1v1==>Pass
#         ! has_race==>Pass
#         ! matchup==>Pass
#         game_len==>Fail
# on 382: Replay skipped, reason:
#         Stopped by filter: ! is_ladder==>Pass
#         ! league==>Pass
#         ! time_played==>Pass
#         ! is_1v1==>Pass
#         ! has_race==>Pass
#         ! matchup==>Pass
#         game_len==>Fail
# on 406: Replay skipped, reason:
#         Stopped by filter: ! is_ladder==>Pass
#         ! league==>Pass
#         ! time_played==>Pass
#         ! is_1v1==>Pass
#         ! has_race==>Pass
#         ! matchup==>Pass
#         game_len==>Fail
# on 408: Replay skipped, reason:
#         Stopped by filter: ! is_ladder==>Pass
#         ! league==>Pass
#         ! time_played==>Pass
#         ! is_1v1==>Pass
#         ! has_race==>Pass
#         ! matchup==>Pass
#         game_len==>Fail
# on 434: Replay skipped, reason:
#         Stopped by filter: ! is_ladder==>Pass
#         ! league==>Pass
#         ! time_played==>Pass
#         ! is_1v1==>Pass
#         ! has_race==>Pass
#         ! matchup==>Pass
#         game_len==>Fail
# on 460: Replay skipped, reason:
#         Stopped by filter: ! is_ladder==>Pass
#         ! league==>Pass
#         ! time_played==>Pass
#         ! is_1v1==>Pass
#         ! has_race==>Pass
#         ! matchup==>Pass
#         game_len==>Fail
# on 515: Replay skipped, reason:
#         Stopped by filter: ! is_ladder==>Pass
#         ! league==>Pass
#         ! time_played==>Pass
#         ! is_1v1==>Pass
#         ! has_race==>Pass
#         ! matchup==>Pass
#         game_len==>Fail
# on 521: Replay skipped, reason:
#         Stopped by filter: ! is_ladder==>Pass
#         ! league==>Pass
#         ! time_played==>Pass
#         ! is_1v1==>Pass
#         ! has_race==>Pass
#         ! matchup==>Pass
#         game_len==>Fail
# on 522: Replay skipped, reason:
#         Stopped by filter: ! is_ladder==>Pass
#         ! league==>Pass
#         ! time_played==>Pass
#         ! is_1v1==>Pass
#         ! has_race==>Pass
#         ! matchup==>Pass
#         game_len==>Fail
# on 599: Replay skipped, reason:
#         Stopped by filter: ! is_ladder==>Pass
#         ! league==>Pass
#         ! time_played==>Pass
#         ! is_1v1==>Pass
#         ! has_race==>Pass
#         ! matchup==>Pass
#         game_len==>Fail
# on 606: Replay skipped, reason:
#         Stopped by filter: ! is_ladder==>Pass
#         ! league==>Pass
#         ! time_played==>Pass
#         ! is_1v1==>Pass
#         ! has_race==>Pass
#         ! matchup==>Pass
#         game_len==>Fail
# on 609: Replay skipped, reason:
#         Stopped by filter: ! is_ladder==>Pass
#         ! league==>Pass
#         ! time_played==>Pass
#         ! is_1v1==>Pass
#         ! has_race==>Pass
#         ! matchup==>Pass
#         game_len==>Fail
# on 628: Replay skipped, reason:
#         Stopped by filter: ! is_ladder==>Pass
#         ! league==>Pass
#         ! time_played==>Pass
#         ! is_1v1==>Pass
#         ! has_race==>Pass
#         ! matchup==>Pass
#         game_len==>Fail
# on 639: Replay skipped, reason:
#         Stopped by filter: ! is_ladder==>Pass
#         ! league==>Pass
#         ! time_played==>Pass
#         ! is_1v1==>Pass
#         ! has_race==>Pass
#         ! matchup==>Pass
#         game_len==>Fail
# on 646: Replay skipped, reason:
#         Stopped by filter: ! is_ladder==>Pass
#         ! league==>Pass
#         ! time_played==>Pass
#         ! is_1v1==>Pass
#         ! has_race==>Pass
#         ! matchup==>Pass
#         game_len==>Fail
# on 656: Replay skipped, reason:
#         Stopped by filter: ! is_ladder==>Pass
#         ! league==>Pass
#         ! time_played==>Pass
#         ! is_1v1==>Pass
#         ! has_race==>Pass
#         ! matchup==>Pass
#         game_len==>Fail
# on 667: Replay skipped, reason:
#         Stopped by filter: ! is_ladder==>Pass
#         ! league==>Pass
#         ! time_played==>Pass
#         ! is_1v1==>Pass
#         ! has_race==>Pass
#         ! matchup==>Pass
#         game_len==>Fail
# on 702: Replay skipped, reason:
#         Stopped by filter: ! is_ladder==>Pass
#         ! league==>Pass
#         ! time_played==>Pass
#         ! is_1v1==>Pass
#         ! has_race==>Pass
#         ! matchup==>Pass
#         game_len==>Fail
# on 706: Replay skipped, reason:
#         Stopped by filter: ! is_ladder==>Pass
#         ! league==>Pass
#         ! time_played==>Pass
#         ! is_1v1==>Pass
#         ! has_race==>Pass
#         ! matchup==>Pass
#         game_len==>Fail
# on 711: Replay skipped, reason:
#         Stopped by filter: ! is_ladder==>Pass
#         ! league==>Pass
#         ! time_played==>Pass
#         ! is_1v1==>Pass
#         ! has_race==>Pass
#         ! matchup==>Pass
#         game_len==>Fail
# |███████████                             | ▆█▆ 714/2601 [27%] in 3:34:30 (~9:26:

# %%
# Run this line to save output of the previous cell
processor.process_replays(REPLAY_DIR, filt=replay_filter)
# Out:
# on 0: Replay skipped, reason:
#       Already exists in the db (path updated)
# on 1: Replay skipped, reason:
#       Already exists in the db (path updated)
# on 2: Replay skipped, reason:
#       Already exists in the db (path updated)
# on 3: Replay skipped, reason:
#       Already exists in the db (path updated)
# on 4: Replay skipped, reason:
#       Already exists in the db (path updated)
# on 5: Replay skipped, reason:
#       Already exists in the db (path updated)
# on 6: Replay skipped, reason:
#       Already exists in the db (path updated)
# on 7: Replay skipped, reason:
#       Stopped by filter: ! is_ladder==>Pass
#       ! league==>Pass
#       ! time_played==>Pass
#       ! is_1v1==>Pass
#       ! has_race==>Pass
#       ! matchup==>Pass
#       game_len==>Fail
# on 8: Replay skipped, reason:
#       Stopped by filter: ! is_ladder==>Pass
#       ! league==>Pass
#       ! time_played==>Pass
#       ! is_1v1==>Pass
#       ! has_race==>Pass
#       ! matchup==>Pass
#       game_len==>Fail
# on 9: Replay skipped, reason:
#       Already exists in the db (path updated)
# on 10: Replay skipped, reason:
#        Already exists in the db (path updated)
# on 11: Replay skipped, reason:
#        Already exists in the db (path updated)
# on 12: Replay skipped, reason:
#        Already exists in the db (path updated)
# on 13: Replay skipped, reason:
#        Already exists in the db (path updated)
# on 14: Replay skipped, reason:
#        Already exists in the db (path updated)
# on 15: Replay skipped, reason:
#        Already exists in the db (path updated)
# on 16: Replay skipped, reason:
#        Already exists in the db (path updated)
# on 17: Replay skipped, reason:
#        Already exists in the db (path updated)
# on 18: Replay skipped, reason:
#        Already exists in the db (path updated)
# on 19: Replay skipped, reason:
#        Already exists in the db (path updated)
# on 20: Replay skipped, reason:
#        Already exists in the db (path updated)
# on 21: Replay skipped, reason:
#        Already exists in the db (path updated)
# on 22: Replay skipped, reason:
#        Already exists in the db (path updated)
# on 23: Replay skipped, reason:
#        Already exists in the db (path updated)
# on 24: Replay skipped, reason:
#        Already exists in the db (path updated)
# on 25: Replay skipped, reason:
#        Already exists in the db (path updated)
# on 26: Replay skipped, reason:
#        Already exists in the db (path updated)
# on 27: Replay skipped, reason:
#        Already exists in the db (path updated)
# on 28: Replay skipped, reason:
#        Already exists in the db (path updated)
# on 29: Replay skipped, reason:
#        Already exists in the db (path updated)
# on 30: Replay skipped, reason:
#        Already exists in the db (path updated)
# on 31: Replay skipped, reason:
#        Already exists in the db (path updated)
# on 32: Replay skipped, reason:
#        Already exists in the db (path updated)
# on 33: Replay skipped, reason:
#        Stopped by filter: ! is_ladder==>Pass
#        ! league==>Pass
#        ! time_played==>Pass
#        ! is_1v1==>Pass
#        ! has_race==>Pass
#        ! matchup==>Pass
#        game_len==>Fail
# on 34: Replay skipped, reason:
#        Stopped by filter: ! is_ladder==>Pass
#        ! league==>Pass
#        ! time_played==>Pass
#        ! is_1v1==>Pass
#        ! has_race==>Pass
#        ! matchup==>Pass
#        game_len==>Fail
# on 35: Replay skipped, reason:
#        Already exists in the db (path updated)
# on 36: Replay skipped, reason:
#        Already exists in the db (path updated)
# on 37: Replay skipped, reason:
#        Already exists in the db (path updated)
# on 38: Replay skipped, reason:
#        Already exists in the db (path updated)
# on 39: Replay skipped, reason:
#        Already exists in the db (path updated)
# on 40: Replay skipped, reason:
#        Already exists in the db (path updated)
# on 41: Replay skipped, reason:
#        Already exists in the db (path updated)
# on 42: Replay skipped, reason:
#        Already exists in the db (path updated)
# on 43: Replay skipped, reason:
#        Already exists in the db (path updated)
# on 44: Replay skipped, reason:
#        Already exists in the db (path updated)
# on 45: Replay skipped, reason:
#        Already exists in the db (path updated)
# on 46: Replay skipped, reason:
#        Already exists in the db (path updated)
# on 47: Replay skipped, reason:
#        Already exists in the db (path updated)
# on 48: Replay skipped, reason:
#        Already exists in the db (path updated)
# on 49: Replay skipped, reason:
#        Already exists in the db (path updated)
# on 50: Replay skipped, reason:
#        Already exists in the db (path updated)
# on 51: Replay skipped, reason:
#        Already exists in the db (path updated)
# on 52: Replay skipped, reason:
#        Already exists in the db (path updated)
# on 53: Replay skipped, reason:
#        Already exists in the db (path updated)
# on 54: Replay skipped, reason:
#        Already exists in the db (path updated)
# on 55: Replay skipped, reason:
#        Already exists in the db (path updated)
# on 56: Replay skipped, reason:
#        Stopped by filter: ! is_ladder==>Pass
#        ! league==>Pass
#        ! time_played==>Pass
#        ! is_1v1==>Pass
#        ! has_race==>Pass
#        ! matchup==>Pass
#        game_len==>Fail
# on 57: Replay skipped, reason:
#        Already exists in the db (path updated)
# on 58: Replay skipped, reason:
#        Already exists in the db (path updated)
# on 59: Replay skipped, reason:
#        Already exists in the db (path updated)
# on 60: Replay skipped, reason:
#        Already exists in the db (path updated)
# on 61: Replay skipped, reason:
#        Already exists in the db (path updated)
# on 62: Replay skipped, reason:
#        Already exists in the db (path updated)
# on 63: Replay skipped, reason:
#        Already exists in the db (path updated)
# on 64: Replay skipped, reason:
#        Already exists in the db (path updated)
# on 65: Replay skipped, reason:
#        Already exists in the db (path updated)
# on 66: Replay skipped, reason:
#        Stopped by filter: ! is_ladder==>Pass
#        ! league==>Pass
#        ! time_played==>Pass
#        ! is_1v1==>Pass
#        ! has_race==>Pass
#        ! matchup==>Pass
#        game_len==>Fail
# on 67: Replay skipped, reason:
#        Already exists in the db (path updated)
# on 68: Replay skipped, reason:
#        Already exists in the db (path updated)
# on 69: Replay skipped, reason:
#        Already exists in the db (path updated)
# on 70: Replay skipped, reason:
#        Already exists in the db (path updated)
# on 71: Replay skipped, reason:
#        Stopped by filter: ! is_ladder==>Pass
#        ! league==>Pass
#        ! time_played==>Pass
#        ! is_1v1==>Pass
#        ! has_race==>Pass
#        ! matchup==>Pass
#        game_len==>Fail
# on 72: Replay skipped, reason:
#        Already exists in the db (path updated)
# on 73: Replay skipped, reason:
#        Already exists in the db (path updated)
# on 74: Replay skipped, reason:
#        Already exists in the db (path updated)
# on 75: Replay skipped, reason:
#        Already exists in the db (path updated)
# on 76: Replay skipped, reason:
#        Already exists in the db (path updated)
# on 77: Replay skipped, reason:
#        Stopped by filter: ! is_ladder==>Pass
#        ! league==>Pass
#        ! time_played==>Pass
#        ! is_1v1==>Pass
#        ! has_race==>Pass
#        ! matchup==>Pass
#        game_len==>Fail
# on 78: Replay skipped, reason:
#        Already exists in the db (path updated)
# on 79: Replay skipped, reason:
#        Already exists in the db (path updated)
# on 80: Replay skipped, reason:
#        Already exists in the db (path updated)
# on 81: Replay skipped, reason:
#        Already exists in the db (path updated)
# on 82: Replay skipped, reason:
#        Stopped by filter: ! is_ladder==>Pass
#        ! league==>Pass
#        ! time_played==>Pass
#        ! is_1v1==>Pass
#        ! has_race==>Pass
#        ! matchup==>Pass
#        game_len==>Fail
# on 83: Replay skipped, reason:
#        Already exists in the db (path updated)
# on 84: Replay skipped, reason:
#        Already exists in the db (path updated)
# on 85: Replay skipped, reason:
#        Already exists in the db (path updated)
# on 86: Replay skipped, reason:
#        Already exists in the db (path updated)
# on 87: Replay skipped, reason:
#        Stopped by filter: ! is_ladder==>Pass
#        ! league==>Pass
#        ! time_played==>Pass
#        ! is_1v1==>Pass
#        ! has_race==>Pass
#        ! matchup==>Pass
#        game_len==>Fail
# on 88: Replay skipped, reason:
#        Stopped by filter: ! is_ladder==>Pass
#        ! league==>Pass
#        ! time_played==>Pass
#        ! is_1v1==>Pass
#        ! has_race==>Pass
#        ! matchup==>Pass
#        game_len==>Fail
# on 89: Replay skipped, reason:
#        Already exists in the db (path updated)
# on 90: Replay skipped, reason:
#        Already exists in the db (path updated)
# on 91: Replay skipped, reason:
#        Already exists in the db (path updated)
# on 92: Replay skipped, reason:
#        Already exists in the db (path updated)
# on 93: Replay skipped, reason:
#        Already exists in the db (path updated)
# on 94: Replay skipped, reason:
#        Already exists in the db (path updated)
# on 95: Replay skipped, reason:
#        Already exists in the db (path updated)
# on
Replay skipped, reason:
#          Stopped by filter: ! is_ladder==>Pass
#          ! league==>Pass
#          ! time_played==>Pass
#          is_1v1==>Fail
#          ! has_race==>Pass
#          ! matchup==>Pass
#          ! game_len==>Pass
# on 2074: Replay skipped, reason:
#          Stopped by filter: ! is_ladder==>Pass
#          ! league==>Pass
#          ! time_played==>Pass
#          ! is_1v1==>Pass
#          ! has_race==>Pass
#          ! matchup==>Pass
#          game_len==>Fail
# on 2086: Replay skipped, reason:
#          Stopped by filter: ! is_ladder==>Pass
#          ! league==>Pass
#          ! time_played==>Pass
#          ! is_1v1==>Pass
#          ! has_race==>Pass
#          ! matchup==>Pass
#          game_len==>Fail
# on 2092: Replay skipped, reason:
#          Stopped by filter: ! is_ladder==>Pass
#          ! league==>Pass
#          ! time_played==>Pass
#          ! is_1v1==>Pass
#          ! has_race==>Pass
#          ! matchup==>Pass
#          game_len==>Fail
# on 2094: Replay skipped, reason:
#          Stopped by filter: ! is_ladder==>Pass
#          ! league==>Pass
#          ! time_played==>Pass
#          ! is_1v1==>Pass
#          ! has_race==>Pass
#          ! matchup==>Pass
#          game_len==>Fail
# on 2101: Replay skipped, reason:
#          Stopped by filter: ! is_ladder==>Pass
#          ! league==>Pass
#          ! time_played==>Pass
#          ! is_1v1==>Pass
#          ! has_race==>Pass
#          ! matchup==>Pass
#          game_len==>Fail
# on 2104: Replay skipped, reason:
#          Stopped by filter: ! is_ladder==>Pass
#          ! league==>Pass
#          ! time_played==>Pass
#          ! is_1v1==>Pass
#          ! has_race==>Pass
#          ! matchup==>Pass
#          game_len==>Fail
# on 2106: Replay skipped, reason:
#          Stopped by filter: ! is_ladder==>Pass
#          ! league==>Pass
#          ! time_played==>Pass
#          ! is_1v1==>Pass
#          ! has_race==>Pass
#          ! matchup==>Pass
#          game_len==>Fail
# on 2120: Replay skipped, reason:
#          Stopped by filter: ! is_ladder==>Pass
#          ! league==>Pass
#          ! time_played==>Pass
#          ! is_1v1==>Pass
#          ! has_race==>Pass
#          ! matchup==>Pass
#          game_len==>Fail
# on 2125: Replay skipped, reason:
#          Stopped by filter: ! is_ladder==>Pass
#          ! league==>Pass
#          ! time_played==>Pass
#          ! is_1v1==>Pass
#          ! has_race==>Pass
#          ! matchup==>Pass
#          game_len==>Fail
# on 2126: Replay skipped, reason:
#          Stopped by filter: ! is_ladder==>Pass
#          ! league==>Pass
#          ! time_played==>Pass
#          ! is_1v1==>Pass
#          ! has_race==>Pass
#          ! matchup==>Pass
#          game_len==>Fail
# on 2144: Replay skipped, reason:
#          Stopped by filter: ! is_ladder==>Pass
#          ! league==>Pass
#          ! time_played==>Pass
#          ! is_1v1==>Pass
#          ! has_race==>Pass
#          ! matchup==>Pass
#          game_len==>Fail
# on 2152: Replay skipped, reason:
#          Stopped by filter: ! is_ladder==>Pass
#          ! league==>Pass
#          ! time_played==>Pass
#          ! is_1v1==>Pass
#          ! has_race==>Pass
#          ! matchup==>Pass
#          game_len==>Fail
# on 2153: Replay skipped, reason:
#          Stopped by filter: ! is_ladder==>Pass
#          ! league==>Pass
#          ! time_played==>Pass
#          ! is_1v1==>Pass
#          ! has_race==>Pass
#          ! matchup==>Pass
#          game_len==>Fail
# on 2164: Replay skipped, reason:
#          Stopped by filter: ! is_ladder==>Pass
#          ! league==>Pass
#          ! time_played==>Pass
#          ! is_1v1==>Pass
#          ! has_race==>Pass
#          ! matchup==>Pass
#          game_len==>Fail
# on 2189: Replay skipped, reason:
#          Stopped by filter: ! is_ladder==>Pass
#          ! league==>Pass
#          ! time_played==>Pass
#          ! is_1v1==>Pass
#          ! has_race==>Pass
#          ! matchup==>Pass
#          game_len==>Fail
# on 2208: Replay skipped, reason:
#          Stopped by filter: ! is_ladder==>Pass
#          ! league==>Pass
#          ! time_played==>Pass
#          ! is_1v1==>Pass
#          ! has_race==>Pass
#          ! matchup==>Pass
#          game_len==>Fail
# on 2211: Replay skipped, reason:
#          Stopped by filter: ! is_ladder==>Pass
#          ! league==>Pass
#          ! time_played==>Pass
#          ! is_1v1==>Pass
#          ! has_race==>Pass
#          ! matchup==>Pass
#          game_len==>Fail
# on 2224: Replay skipped, reason:
#          Stopped by filter: ! is_ladder==>Pass
#          ! league==>Pass
#          ! time_played==>Pass
#          ! is_1v1==>Pass
#          ! has_race==>Pass
#          ! matchup==>Pass
#          game_len==>Fail
# on 2230: Replay skipped, reason:
#          Stopped by filter: ! is_ladder==>Pass
#          ! league==>Pass
#          ! time_played==>Pass
#          ! is_1v1==>Pass
#          ! has_race==>Pass
#          ! matchup==>Pass
#          game_len==>Fail
# on 2272: Replay skipped, reason:
#          Stopped by filter: ! is_ladder==>Pass
#          ! league==>Pass
#          ! time_played==>Pass
#          ! is_1v1==>Pass
#          ! has_race==>Pass
#          ! matchup==>Pass
#          game_len==>Fail
# on 2273: Replay skipped, reason:
#          Stopped by filter: ! is_ladder==>Pass
#          ! league==>Pass
#          ! time_played==>Pass
#          ! is_1v1==>Pass
#          ! has_race==>Pass
#          ! matchup==>Pass
#          game_len==>Fail
# on 2279: Replay skipped, reason:
#          Stopped by filter: ! is_ladder==>Pass
#          ! league==>Pass
#          ! time_played==>Pass
#          ! is_1v1==>Pass
#          ! has_race==>Pass
#          ! matchup==>Pass
#          game_len==>Fail
# on 2284: Replay skipped, reason:
#          list index out of range
# on 2286: Replay skipped, reason:
#          Stopped by filter: ! is_ladder==>Pass
#          ! league==>Pass
#          ! time_played==>Pass
#          ! is_1v1==>Pass
#          ! has_race==>Pass
#          ! matchup==>Pass
#          game_len==>Fail
# on 2288: Replay skipped, reason:
#          Stopped by filter: ! is_ladder==>Pass
#          ! league==>Pass
#          ! time_played==>Pass
#          ! is_1v1==>Pass
#          ! has_race==>Pass
#          ! matchup==>Pass
#          game_len==>Fail
# on 2291: Replay skipped, reason:
#          Stopped by filter: ! is_ladder==>Pass
#          ! league==>Pass
#          ! time_played==>Pass
#          ! is_1v1==>Pass
#          ! has_race==>Pass
#          ! matchup==>Pass
#          game_len==>Fail
# on 2292: Replay skipped, reason:
#          Stopped by filter: ! is_ladder==>Pass
#          ! league==>Pass
#          ! time_played==>Pass
#          ! is_1v1==>Pass
#          ! has_race==>Pass
#          ! matchup==>Pass
#          game_len==>Fail
# on 2293: Replay skipped, reason:
#          ''
# on 2297: Replay skipped, reason:
#          'Изначальные зерги'
# on 2300: Replay skipped, reason:
#          Stopped by filter: ! is_ladder==>Pass
#          ! league==>Pass
#          ! time_played==>Pass
#          is_1v1==>Fail
#          ! has_race==>Pass
#          ! matchup==>Pass
#          ! game_len==>Pass
# on 2304: Replay skipped, reason:
#          list index out of range
# on 2308: Replay skipped, reason:
#          'Изначальные зерги'
# on 2309: Replay skipped, reason:
#          '人类 UED'
# on 2310: Replay skipped, reason:
#          'Protoss Ulrezaj'
# on 2311: Replay skipped, reason:
#          Stopped by filter: ! is_ladder==>Pass
#          ! league==>Pass
#          ! time_played==>Pass
#          ! is_1v1==>Pass
#          ! has_race==>Pass
#          ! matchup==>Pass
#          game_len==>Fail
# on 2317: Replay skipped, reason:
#          Stopped by filter: ! is_ladder==>Pass
#          ! league==>Pass
#          ! time_played==>Pass
#          ! is_1v1==>Pass
#          ! has_race==>Pass
#          ! matchup==>Pass
#          game_len==>Fail
# |███████████████████████████████████▊⚠︎   | (!) 2321/2601 [89%] in 8:06:26.9 (0.0
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[6], line 2
#       1 # Run this line to save output of the previous cell
# ----> 2 processor.process_replays(REPLAY_DIR, filt=replay_filter)
#
# File /run/media/dvarkless/LinuxData/Files/PythonProjects/sc2bot/sc2-replay-converter/replay_process.py:428, in ReplayProcess.process_replays(self, replay_dir, filt)
#     426     self.upload_player_info(replay)
#     427     id = self.upload_game_info(replay, replay_path)
# --> 428     self.upload_build_order(replay, id, bar=bar)
#     429 else:
#     430     with self.game_info_db:
#
# File /run/media/dvarkless/LinuxData/Files/PythonProjects/sc2bot/sc2-replay-converter/replay_process.py:364, in ReplayProcess.upload_build_order(self, replay, game_id, bar)
#     362 replay_data = replay.as_dict()
#     363 full_upload_dict = dict()
# --> 364 for i, build_order_dict in enumerate(
#     365     self.build_order_cls.yield_unit_counts(replay_data)
#     366 ):
#     367     for key, val in build_order_dict.items():
#     368         try:
#
# File /run/media/dvarkless/LinuxData/Files/PythonProjects/sc2bot/sc2-replay-converter/starcraft2_replay_parse/replay_tools.py:298, in BuildOrderData.yield_unit_counts(self, replay_data_dict)
#     295     else:
#     296         regular_events.append(event)
# --> 298 dense_dict = self.get_density_from_events(regular_events)
#     299 build_order_dict = self.get_build_order_from_density(dense_dict)
#     301 build_order_special = self.get_build_order_special(specific_events)
#
# File /run/media/dvarkless/LinuxData/Files/PythonProjects/sc2bot/sc2-replay-converter/starcraft2_replay_parse/replay_tools.py:325, in BuildOrderData.get_density_from_events(self, event_list)
#     323 density_dict = self.init_zeros_density()
#     324 for time_pos, event_name, event_value in event_list:
# --> 325     density_dict[event_name][time_pos // self.bin_size_ticks] += event_value
#     327 return density_dict
#
# KeyError: 'MultiplayerSupply'
